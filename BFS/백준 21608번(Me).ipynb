# %%
N = int(input())

arr = [[0]*N for _ in range(N)]
hopeList = {}

def setPosition(num, hopeList):
  for hope in hopeList[num]:
    if hope in arr:
      x, y = arr.index(hope)
      print(x, y,'-----')
      if arr[x-1][y] == 0 and x-1 >= 0:
        arr[x-1][y] = num
        return True
      elif arr[x][y-1] == 0 and y-1 >= 0:
        arr[x][y-1] = num
        return True
      elif arr[x][y+1] == 0 and y+1 >= 0:
        arr[x][y+1] = num
        return True
      elif arr[x+1][y] == 0 and x+1 >= 0:
        arr[x+1][y] = num
        return True
  for i in N:
    for j in N:
      if arr[i][j] == 0:

for _ in range(N*N):
  num, h1, h2, h3, h4 = map(int, input().split())

  hopeList[num] = [h1, h2, h3, h4]
  setPosition(num, hopeList)

answer = 0
for i in N:
  for j in N:
    for hope in hopeList[arr[i][j]]:
      if arr[i-1][j] == hope and i-1 > 0:
        count += 1
        continue
      elif arr[i][j-1] == hope and j-1 > 0:
        count += 1
        continue
      elif arr[i][j+1] == hope and j+1 < N:
        count += 1
        continue
      elif arr[i+1][j] == hope and i+1 < N:
        count +=1
        continue

    if count == 0:
      pass
    elif count == 1:
      answer += 1
    elif count == 2:
      answer += 10
    elif count == 3:
      answer += 100
    else:
      answer += 1000

print(answer)
